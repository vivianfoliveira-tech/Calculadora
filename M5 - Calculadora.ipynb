# %%
num1 = int(input("Digite o número 1:"))
num2 = int(input("Digite o número 2:"))
# Out:
# Digite o número 1:5
# Digite o número 2:8

# %%
num1_float = float(num1)
num2_float = float(num2)

print(f"Número inteiro: {num1} | Número float: {num1_float}")
print(f"Número inteiro: {num2} | Número float: {num2_float}")
# Out:
# Número inteiro: 5 | Número float: 5.0
# Número inteiro: 8 | Número float: 8.0

# %%
# Definindo as variáveis
a = 10
b = 7

# Operações matemáticas
soma = a + b
multiplicacao = a * b
divisao = a / b
resto = a % b

# Exibindo os resultados
print("Soma:", soma)
print("Multiplicação:", multiplicacao)
print("Divisão:", divisao)
print("Resto:", resto)
# Out:
# Soma: 17
# Multiplicação: 70
# Divisão: 1.4285714285714286
# Resto: 3

# %%
print("=== Calculadora ===")

while True:
    # Menu
    print("\nEscolha a operação:")
    print("1 - Soma")
    print("2 - Multiplicação")
    print("3 - Divisão")
    print("4 - Resto")
    print("0 - Sair")

    opcao = input("Opção: ").strip()

    if opcao == "0":
        print("Encerrando...")
        break

    if opcao not in {"1", "2", "3", "4"}:
        print("Opção inválida. Tente novamente.")
        continue

    # Entrada dos números
    try:
        num1 = float(input("Digite o primeiro número: ").replace(",", "."))
        num2 = float(input("Digite o segundo número: ").replace(",", "."))
    except ValueError:
        print("Entrada inválida. Digite apenas números.")
        continue

    # Operações
    if opcao == "1":
        print("Resultado:", num1 + num2)

    elif opcao == "2":
        print("Resultado:", num1 * num2)

    elif opcao == "3":
        if num2 == 0:
            print("Erro: divisão por zero!")
        else:
            print("Resultado:", num1 / num2)

    elif opcao == "4":
        if num2 == 0:
            print("Erro: resto por zero não existe!")
        else:
            print("Resultado:", num1 % num2)
# Out:
# === Calculadora ===
#
# Escolha a operação:
# 1 - Soma
# 2 - Multiplicação
# 3 - Divisão
# 4 - Resto
# 0 - Sair
# Opção: 10
# Opção inválida. Tente novamente.
#
# Escolha a operação:
# 1 - Soma
# 2 - Multiplicação
# 3 - Divisão
# 4 - Resto
# 0 - Sair
# Opção: 1
# Digite o primeiro número: 5
# Digite o segundo número: 6
# Resultado: 11.0
#
# Escolha a operação:
# 1 - Soma
# 2 - Multiplicação
# 3 - Divisão
# 4 - Resto
# 0 - Sair
